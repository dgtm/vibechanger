# %%
# !git clone https://github.com/myshell-ai/OpenVoice.git
# %cd OpenVoice

# !pip install -e .
# !pip install git+https://github.com/myshell-ai/MeloTTS.git
# !python -m unidic download
# Out:
# Cloning into 'OpenVoice'...
# remote: Enumerating objects: 460, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 460 (delta 11), reused 7 (delta 7), pack-reused 445 (from 2)
# Receiving objects: 100% (460/460), 3.85 MiB | 2.99 MiB/s, done.
# Resolving deltas: 100% (218/218), done.
# /Users/dipesh/Documents/video/jobs/video_ai/OpenVoice
# Obtaining file:///Users/dipesh/Documents/video/jobs/video_ai/OpenVoice
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting librosa==0.9.1 (from MyShell-OpenVoice==0.0.0)
#   Downloading librosa-0.9.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting faster-whisper==0.9.0 (from MyShell-OpenVoice==0.0.0)
#   Downloading faster_whisper-0.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pydub==0.25.1 in /Users/dipesh/Documents/video/.venv/lib/python3.11/site-packages (from MyShell-OpenVoice==0.0.0) (0.25.1)
# Collecting wavmark==0.0.3 (from MyShell-OpenVoice==0.0.0)
#   Downloading wavmark-0.0.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting numpy==1.22.0 (from MyShell-OpenVoice==0.0.0)
#   Downloading numpy-1.22.0.zip (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 15.2 MB/s  0:00:00m0:00:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting eng_to_ipa==0.0.2 (from MyShell-OpenVoice==0.0.0)
#   Downloading eng_to_ipa-0.0.2.tar.gz (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 16.4 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting inflect==7.0.0 (from MyShell-OpenVoice==0.0.0)
#   Downloading inflect-7.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting unidecode==1.3.7 (from MyShell-OpenVoice==0.0.0)
#   Downloading Unidecode-1.3.7-py3-none-any.whl.metadata (13 kB)
# Collecting whisper-timestamped==1.14.2 (from MyShell-OpenVoice==0.0.0)
#   Downloading whisper_timestamped-1.14.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting pypinyin==0.50.0 (from MyShell-OpenVoice==0.0.0)
#   Downloading pypinyin-0.50.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting cn2an==0.5.22 (from MyShell-OpenVoice==0.0.0)
#   Downloading cn2an-0.5.22-py3-none-any.whl.metadata (10 kB)
# Collecting jieba==0.42.1 (from MyShell-OpenVoice==0.0.0)
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 9.9 MB/s  0:00:026m0:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gradio==3.48.0 (from MyShell-OpenVoice==0.0.0)
#   Downloading gradio-3.48.0-py3-none-any.whl.metadata (17 kB)
# Collecting langid==1.1.6 (from MyShell-OpenVoice==0.0.0)
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.6 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=47.3.1 in /Users/dipesh/Documents/video/.venv/lib/python3.11/site-packages (from cn2an==0.5.22->MyShell-OpenVoice==0.0.0) (79.0.1)
# Collecting proces>=0.1.3 (from cn2an==0.5.22->MyShell-OpenVoice==0.0.0)
#   Downloading proces-0.1.7-py3-none-any.whl.metadata (3.3 kB)
# Collecting av==10.* (from faster-whisper==0.9.0->MyShell-OpenVoice==0.0.0)
#   Downloading av-10.0.0.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 13.9 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [11 lines of output]
#       Package libavformat was not found in the pkg-config search path.
#       Perhaps you should add the directory containing `libavformat.pc'
#       to the PKG_CONFIG_PATH environment variable
#       Package 'libavformat' not found
#       Package 'libavcodec' not found
#       Package 'libavdevice' not found
#       Package 'libavutil' not found
#       Package 'libavfilter' not found
#       Package 'libswscale' not found
#       Package 'libswresample' not found
#       pkg-config could not find libraries ['avformat', 'avcodec', 'avdevice', 'avutil', 'avfilter', 'swscale', 'swresample']
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Failed to build 'av' when getting requirements to build wheel
# Collecting git+https://github.com/myshell-ai/MeloTTS.git
#   Cloning https://github.com/myshell-ai/MeloTTS.git to /private/var/folders/1c/p8tdkpmn2kl1blpvsvw_pvt40000gp/T/pip-req-build-n5hzoqjx
#   Running command git clone --filter=blob:none --quiet https://github.com/myshell-ai/MeloTTS.git /private/var/folders/1c/p8tdkpmn2kl1blpvsvw_pvt40000gp/T/pip-req-build-n5hzoqjx
#   Resolved https://github.com/myshell-ai/MeloTTS.git to commit 209145371cff8fc3bd60d7be902ea69cbdb7965a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting txtsplit (from melotts==0.1.2)
#   Downloading txtsplit-1.0.0.tar.gz (6.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /Users/dipesh/Documents/video/.venv/lib/python3.11/site-packages (from melotts==0.1.2) (2.11.0)
# Collecting torchaudio (from melotts==0.1.2)
#   Downloading torchaudio-2.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.9 kB)
# Collecting cached_path (from melotts==0.1.2)
#   Downloading cached_path-1.8.10-py3-none-any.whl.metadata (19 kB)
# Collecting transformers==4.27.4 (from melotts==0.1.2)
#   Downloading transformers-4.27.4-py3-none-any.whl.metadata (106 kB)
# Collecting num2words==0.5.12 (from melotts==0.1.2)
#   Downloading num2words-0.5.12-py3-none-any.whl.metadata (11 kB)
# Collecting unidic_lite==1.0.8 (from melotts==0.1.2)
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 19.3 MB/s  0:00:02m0:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting unidic==1.1.0 (from melotts==0.1.2)
#   Downloading unidic-1.1.0.tar.gz (7.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mecab-python3==1.0.9 (from melotts==0.1.2)
#   Downloading mecab_python3-1.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Collecting pykakasi==2.2.1 (from melotts==0.1.2)
#   Downloading pykakasi-2.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting fugashi==1.3.0 (from melotts==0.1.2)
#   Downloading fugashi-1.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.0 kB)
# Collecting g2p_en==2.1.0 (from melotts==0.1.2)
#   Downloading g2p_en-2.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting anyascii==0.3.2 (from melotts==0.1.2)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting jamo==0.4.1 (from melotts==0.1.2)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting gruut==2.2.3 (from gruut[de,es,fr]==2.2.3->melotts==0.1.2)
#   Downloading gruut-2.2.3.tar.gz (73 kB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for gruut did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Collecting setuptools>=40.8.0
#         Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
#       Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
#       ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Failed to build 'gruut' when installing build dependencies for gruut
# /Users/dipesh/Documents/video/.venv/bin/python: No module named unidic

# %% [markdown]
# !mkdir -p checkpoints_v2
# %cd checkpoints_v2
#
# !wget https://huggingface.co/myshell-ai/OpenVoiceV2/resolve/main/converter/checkpoint.pth
# !wget https://huggingface.co/myshell-ai/OpenVoiceV2/resolve/main/converter/config.json
#
# %cd ..
